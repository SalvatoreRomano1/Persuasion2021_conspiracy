# %%
def score_func1(morra):
    """ win or lose? """
    if morra['morra1_t1'] == 'Carta' and morra['morraRisp1_t1'] == 'carta':
        return 0.1
    elif morra['morra1_t1'] == 'Carta' and morra['morraRisp1_t1'] == 'sasso':
        return 1.0
    elif morra['morra1_t1'] == 'Carta' and morra['morraRisp1_t1'] == 'forbice':
        return 0.0
    elif morra['morra1_t1'] == 'Sasso' and morra['morraRisp1_t1'] == 'carta':
        return 0.0
    elif morra['morra1_t1'] == 'Sasso' and morra['morraRisp1_t1'] == 'sasso':
        return 0.1
    elif morra['morra1_t1'] == 'Sasso' and morra['morraRisp1_t1'] == 'forbice':
        return 1.0
    elif morra['morra1_t1'] == 'Forbice' and morra['morraRisp1_t1'] == 'carta':
        return 1.0
    elif morra['morra1_t1'] == 'Forbice' and morra['morraRisp1_t1'] == 'sasso':
        return 0.0
    elif morra['morra1_t1'] == 'Forbice' and morra['morraRisp1_t1'] == 'forbice':
        return 0.1
    else:
        return 'errore'

def score_func2(morra):
    """ win or lose? """
    if morra['morra2_t1'] == 'Carta' and morra['morraRisp2_t1'] == 'carta':
        return 0.1
    elif morra['morra2_t1'] == 'Carta' and morra['morraRisp2_t1'] == 'sasso':
        return 1.0
    elif morra['morra2_t1'] == 'Carta' and morra['morraRisp2_t1'] == 'forbice':
        return 0.0
    elif morra['morra2_t1'] == 'Sasso' and morra['morraRisp2_t1'] == 'carta':
        return 0.0
    elif morra['morra2_t1'] == 'Sasso' and morra['morraRisp2_t1'] == 'sasso':
        return 0.1
    elif morra['morra2_t1'] == 'Sasso' and morra['morraRisp2_t1'] == 'forbice':
        return 1.0
    elif morra['morra2_t1'] == 'Forbice' and morra['morraRisp2_t1'] == 'carta':
        return 1.0
    elif morra['morra2_t1'] == 'Forbice' and morra['morraRisp2_t1'] == 'sasso':
        return 0.0
    elif morra['morra2_t1'] == 'Forbice' and morra['morraRisp2_t1'] == 'forbice':
        return 0.1
    else:
        return 'errore'
    
def score_func3(morra):
    """ win or lose? """
    if morra['morra3_t1'] == 'Carta' and morra['morraRisp3_t1'] == 'carta':
        return 0.1
    elif morra['morra3_t1'] == 'Carta' and morra['morraRisp3_t1'] == 'sasso':
        return 1.0
    elif morra['morra3_t1'] == 'Carta' and morra['morraRisp3_t1'] == 'forbice':
        return 0.0
    elif morra['morra3_t1'] == 'Sasso' and morra['morraRisp3_t1'] == 'carta':
        return 0.0
    elif morra['morra3_t1'] == 'Sasso' and morra['morraRisp3_t1'] == 'sasso':
        return 0.1
    elif morra['morra3_t1'] == 'Sasso' and morra['morraRisp3_t1'] == 'forbice':
        return 1.0
    elif morra['morra3_t1'] == 'Forbice' and morra['morraRisp3_t1'] == 'carta':
        return 1.0
    elif morra['morra3_t1'] == 'Forbice' and morra['morraRisp3_t1'] == 'sasso':
        return 0.0
    elif morra['morra3_t1'] == 'Forbice' and morra['morraRisp3_t1'] == 'forbice':
        return 0.1
    else:
        return 'errore'

def score_func4(morra):
    """ win or lose? """
    if morra['morra4_t1'] == 'Carta' and morra['morraRisp4_t1'] == 'carta':
        return 0.1
    elif morra['morra4_t1'] == 'Carta' and morra['morraRisp4_t1'] == 'sasso':
        return 1.0
    elif morra['morra4_t1'] == 'Carta' and morra['morraRisp4_t1'] == 'forbice':
        return 0.0
    elif morra['morra4_t1'] == 'Sasso' and morra['morraRisp4_t1'] == 'carta':
        return 0.0
    elif morra['morra4_t1'] == 'Sasso' and morra['morraRisp4_t1'] == 'sasso':
        return 0.1
    elif morra['morra4_t1'] == 'Sasso' and morra['morraRisp4_t1'] == 'forbice':
        return 1.0
    elif morra['morra4_t1'] == 'Forbice' and morra['morraRisp4_t1'] == 'carta':
        return 1.0
    elif morra['morra4_t1'] == 'Forbice' and morra['morraRisp4_t1'] == 'sasso':
        return 0.0
    elif morra['morra4_t1'] == 'Forbice' and morra['morraRisp4_t1'] == 'forbice':
        return 0.1
    else:
        return 'errore'
    
def score_func5(morra):
    """ win or lose? """
    if morra['morra5_t1'] == 'Carta' and morra['morraRisp5_t1'] == 'carta':
        return 0.1
    elif morra['morra5_t1'] == 'Carta' and morra['morraRisp5_t1'] == 'sasso':
        return 1.0
    elif morra['morra5_t1'] == 'Carta' and morra['morraRisp5_t1'] == 'forbice':
        return 0.0
    elif morra['morra5_t1'] == 'Sasso' and morra['morraRisp5_t1'] == 'carta':
        return 0.0
    elif morra['morra5_t1'] == 'Sasso' and morra['morraRisp5_t1'] == 'sasso':
        return 0.1
    elif morra['morra5_t1'] == 'Sasso' and morra['morraRisp5_t1'] == 'forbice':
        return 1.0
    elif morra['morra5_t1'] == 'Forbice' and morra['morraRisp5_t1'] == 'carta':
        return 1.0
    elif morra['morra5_t1'] == 'Forbice' and morra['morraRisp5_t1'] == 'sasso':
        return 0.0
    elif morra['morra5_t1'] == 'Forbice' and morra['morraRisp5_t1'] == 'forbice':
        return 0.1
    else:
        return 'errore'
    
def score_func6(morra):
    """ win or lose? """
    if morra['morra6_t1'] == 'Carta' and morra['morraRisp6_t1'] == 'carta':
        return 0.1
    elif morra['morra6_t1'] == 'Carta' and morra['morraRisp6_t1'] == 'sasso':
        return 1.0
    elif morra['morra6_t1'] == 'Carta' and morra['morraRisp6_t1'] == 'forbice':
        return 0.0
    elif morra['morra6_t1'] == 'Sasso' and morra['morraRisp6_t1'] == 'carta':
        return 0.0
    elif morra['morra6_t1'] == 'Sasso' and morra['morraRisp6_t1'] == 'sasso':
        return 0.1
    elif morra['morra6_t1'] == 'Sasso' and morra['morraRisp6_t1'] == 'forbice':
        return 1.0
    elif morra['morra6_t1'] == 'Forbice' and morra['morraRisp6_t1'] == 'carta':
        return 1.0
    elif morra['morra6_t1'] == 'Forbice' and morra['morraRisp6_t1'] == 'sasso':
        return 0.0
    elif morra['morra6_t1'] == 'Forbice' and morra['morraRisp6_t1'] == 'forbice':
        return 0.1
    else:
        return 'errore'
def score_func7(morra):
    """ win or lose? """
    if morra['morra7_t1'] == 'Carta' and morra['morraRisp7_t1'] == 'carta':
        return 0.1
    elif morra['morra7_t1'] == 'Carta' and morra['morraRisp7_t1'] == 'sasso':
        return 1.0
    elif morra['morra7_t1'] == 'Carta' and morra['morraRisp7_t1'] == 'forbice':
        return 0.0
    elif morra['morra7_t1'] == 'Sasso' and morra['morraRisp7_t1'] == 'carta':
        return 0.0
    elif morra['morra7_t1'] == 'Sasso' and morra['morraRisp7_t1'] == 'sasso':
        return 0.1
    elif morra['morra7_t1'] == 'Sasso' and morra['morraRisp7_t1'] == 'forbice':
        return 1.0
    elif morra['morra7_t1'] == 'Forbice' and morra['morraRisp7_t1'] == 'carta':
        return 1.0
    elif morra['morra7_t1'] == 'Forbice' and morra['morraRisp7_t1'] == 'sasso':
        return 0.0
    elif morra['morra7_t1'] == 'Forbice' and morra['morraRisp7_t1'] == 'forbice':
        return 0.1
    else:
        return 'errore'

def score_func8(morra):
    """ win or lose? """
    if morra['morra8_t1'] == 'Carta' and morra['morraRisp8_t1'] == 'carta':
        return 0.1
    elif morra['morra8_t1'] == 'Carta' and morra['morraRisp8_t1'] == 'sasso':
        return 1.0
    elif morra['morra8_t1'] == 'Carta' and morra['morraRisp8_t1'] == 'forbice':
        return 0.0
    elif morra['morra8_t1'] == 'Sasso' and morra['morraRisp8_t1'] == 'carta':
        return 0.0
    elif morra['morra8_t1'] == 'Sasso' and morra['morraRisp8_t1'] == 'sasso':
        return 0.1
    elif morra['morra8_t1'] == 'Sasso' and morra['morraRisp8_t1'] == 'forbice':
        return 1.0
    elif morra['morra8_t1'] == 'Forbice' and morra['morraRisp8_t1'] == 'carta':
        return 1.0
    elif morra['morra8_t1'] == 'Forbice' and morra['morraRisp8_t1'] == 'sasso':
        return 0.0
    elif morra['morra8_t1'] == 'Forbice' and morra['morraRisp8_t1'] == 'forbice':
        return 0.1
    else:
        return 'errore'

def score_func9(morra):
    """ win or lose? """
    if morra['morra9_t1'] == 'Carta' and morra['morraRisp9_t1'] == 'carta':
        return 0.1
    elif morra['morra9_t1'] == 'Carta' and morra['morraRisp9_t1'] == 'sasso':
        return 1.0
    elif morra['morra9_t1'] == 'Carta' and morra['morraRisp9_t1'] == 'forbice':
        return 0.0
    elif morra['morra9_t1'] == 'Sasso' and morra['morraRisp9_t1'] == 'carta':
        return 0.0
    elif morra['morra9_t1'] == 'Sasso' and morra['morraRisp9_t1'] == 'sasso':
        return 0.1
    elif morra['morra9_t1'] == 'Sasso' and morra['morraRisp9_t1'] == 'forbice':
        return 1.0
    elif morra['morra9_t1'] == 'Forbice' and morra['morraRisp9_t1'] == 'carta':
        return 1.0
    elif morra['morra9_t1'] == 'Forbice' and morra['morraRisp9_t1'] == 'sasso':
        return 0.0
    elif morra['morra9_t1'] == 'Forbice' and morra['morraRisp9_t1'] == 'forbice':
        return 0.1
    else:
        return 'errore'

def score_func10(morra):
    """ win or lose? """
    if morra['morra10_t1'] == 'Carta' and morra['morraRisp10_t1'] == 'carta':
        return 0.1
    elif morra['morra10_t1'] == 'Carta' and morra['morraRisp10_t1'] == 'sasso':
        return 1.0
    elif morra['morra10_t1'] == 'Carta' and morra['morraRisp10_t1'] == 'forbice':
        return 0.0
    elif morra['morra10_t1'] == 'Sasso' and morra['morraRisp10_t1'] == 'carta':
        return 0.0
    elif morra['morra10_t1'] == 'Sasso' and morra['morraRisp10_t1'] == 'sasso':
        return 0.1
    elif morra['morra10_t1'] == 'Sasso' and morra['morraRisp10_t1'] == 'forbice':
        return 1.0
    elif morra['morra10_t1'] == 'Forbice' and morra['morraRisp10_t1'] == 'carta':
        return 1.0
    elif morra['morra10_t1'] == 'Forbice' and morra['morraRisp10_t1'] == 'sasso':
        return 0.0
    elif morra['morra10_t1'] == 'Forbice' and morra['morraRisp10_t1'] == 'forbice':
        return 0.1
    else:
        return 'errore'

# %%
# fuctions for _t2

def score_func1_t2(morra):
    """ win or lose? """
    if morra['morra1_t2'] == 'Carta' and morra['morraRisp1_t2'] == 'carta':
        return 0.1
    elif morra['morra1_t2'] == 'Carta' and morra['morraRisp1_t2'] == 'sasso':
        return 1.0
    elif morra['morra1_t2'] == 'Carta' and morra['morraRisp1_t2'] == 'forbice':
        return 0.0
    elif morra['morra1_t2'] == 'Sasso' and morra['morraRisp1_t2'] == 'carta':
        return 0.0
    elif morra['morra1_t2'] == 'Sasso' and morra['morraRisp1_t2'] == 'sasso':
        return 0.1
    elif morra['morra1_t2'] == 'Sasso' and morra['morraRisp1_t2'] == 'forbice':
        return 1.0
    elif morra['morra1_t2'] == 'Forbice' and morra['morraRisp1_t2'] == 'carta':
        return 1.0
    elif morra['morra1_t2'] == 'Forbice' and morra['morraRisp1_t2'] == 'sasso':
        return 0.0
    elif morra['morra1_t2'] == 'Forbice' and morra['morraRisp1_t2'] == 'forbice':
        return 0.1
    else:
        return 'errore'

def score_func2_t2(morra):
    """ win or lose? """
    if morra['morra2_t2'] == 'Carta' and morra['morraRisp2_t2'] == 'carta':
        return 0.1
    elif morra['morra2_t2'] == 'Carta' and morra['morraRisp2_t2'] == 'sasso':
        return 1.0
    elif morra['morra2_t2'] == 'Carta' and morra['morraRisp2_t2'] == 'forbice':
        return 0.0
    elif morra['morra2_t2'] == 'Sasso' and morra['morraRisp2_t2'] == 'carta':
        return 0.0
    elif morra['morra2_t2'] == 'Sasso' and morra['morraRisp2_t2'] == 'sasso':
        return 0.1
    elif morra['morra2_t2'] == 'Sasso' and morra['morraRisp2_t2'] == 'forbice':
        return 1.0
    elif morra['morra2_t2'] == 'Forbice' and morra['morraRisp2_t2'] == 'carta':
        return 1.0
    elif morra['morra2_t2'] == 'Forbice' and morra['morraRisp2_t2'] == 'sasso':
        return 0.0
    elif morra['morra2_t2'] == 'Forbice' and morra['morraRisp2_t2'] == 'forbice':
        return 0.1
    else:
        return 'errore'
    
def score_func3_t2(morra):
    """ win or lose? """
    if morra['morra3_t2'] == 'Carta' and morra['morraRisp3_t2'] == 'carta':
        return 0.1
    elif morra['morra3_t2'] == 'Carta' and morra['morraRisp3_t2'] == 'sasso':
        return 1.0
    elif morra['morra3_t2'] == 'Carta' and morra['morraRisp3_t2'] == 'forbice':
        return 0.0
    elif morra['morra3_t2'] == 'Sasso' and morra['morraRisp3_t2'] == 'carta':
        return 0.0
    elif morra['morra3_t2'] == 'Sasso' and morra['morraRisp3_t2'] == 'sasso':
        return 0.1
    elif morra['morra3_t2'] == 'Sasso' and morra['morraRisp3_t2'] == 'forbice':
        return 1.0
    elif morra['morra3_t2'] == 'Forbice' and morra['morraRisp3_t2'] == 'carta':
        return 1.0
    elif morra['morra3_t2'] == 'Forbice' and morra['morraRisp3_t2'] == 'sasso':
        return 0.0
    elif morra['morra3_t2'] == 'Forbice' and morra['morraRisp3_t2'] == 'forbice':
        return 0.1
    else:
        return 'errore'

def score_func4_t2(morra):
    """ win or lose? """
    if morra['morra4_t2'] == 'Carta' and morra['morraRisp4_t2'] == 'carta':
        return 0.1
    elif morra['morra4_t2'] == 'Carta' and morra['morraRisp4_t2'] == 'sasso':
        return 1.0
    elif morra['morra4_t2'] == 'Carta' and morra['morraRisp4_t2'] == 'forbice':
        return 0.0
    elif morra['morra4_t2'] == 'Sasso' and morra['morraRisp4_t2'] == 'carta':
        return 0.0
    elif morra['morra4_t2'] == 'Sasso' and morra['morraRisp4_t2'] == 'sasso':
        return 0.1
    elif morra['morra4_t2'] == 'Sasso' and morra['morraRisp4_t2'] == 'forbice':
        return 1.0
    elif morra['morra4_t2'] == 'Forbice' and morra['morraRisp4_t2'] == 'carta':
        return 1.0
    elif morra['morra4_t2'] == 'Forbice' and morra['morraRisp4_t2'] == 'sasso':
        return 0.0
    elif morra['morra4_t2'] == 'Forbice' and morra['morraRisp4_t2'] == 'forbice':
        return 0.1
    else:
        return 'errore'
    
def score_func5_t2(morra):
    """ win or lose? """
    if morra['morra5_t2'] == 'Carta' and morra['morraRisp5_t2'] == 'carta':
        return 0.1
    elif morra['morra5_t2'] == 'Carta' and morra['morraRisp5_t2'] == 'sasso':
        return 1.0
    elif morra['morra5_t2'] == 'Carta' and morra['morraRisp5_t2'] == 'forbice':
        return 0.0
    elif morra['morra5_t2'] == 'Sasso' and morra['morraRisp5_t2'] == 'carta':
        return 0.0
    elif morra['morra5_t2'] == 'Sasso' and morra['morraRisp5_t2'] == 'sasso':
        return 0.1
    elif morra['morra5_t2'] == 'Sasso' and morra['morraRisp5_t2'] == 'forbice':
        return 1.0
    elif morra['morra5_t2'] == 'Forbice' and morra['morraRisp5_t2'] == 'carta':
        return 1.0
    elif morra['morra5_t2'] == 'Forbice' and morra['morraRisp5_t2'] == 'sasso':
        return 0.0
    elif morra['morra5_t2'] == 'Forbice' and morra['morraRisp5_t2'] == 'forbice':
        return 0.1
    else:
        return 'errore'
    
def score_func6_t2(morra):
    """ win or lose? """
    if morra['morra6_t2'] == 'Carta' and morra['morraRisp6_t2'] == 'carta':
        return 0.1
    elif morra['morra6_t2'] == 'Carta' and morra['morraRisp6_t2'] == 'sasso':
        return 1.0
    elif morra['morra6_t2'] == 'Carta' and morra['morraRisp6_t2'] == 'forbice':
        return 0.0
    elif morra['morra6_t2'] == 'Sasso' and morra['morraRisp6_t2'] == 'carta':
        return 0.0
    elif morra['morra6_t2'] == 'Sasso' and morra['morraRisp6_t2'] == 'sasso':
        return 0.1
    elif morra['morra6_t2'] == 'Sasso' and morra['morraRisp6_t2'] == 'forbice':
        return 1.0
    elif morra['morra6_t2'] == 'Forbice' and morra['morraRisp6_t2'] == 'carta':
        return 1.0
    elif morra['morra6_t2'] == 'Forbice' and morra['morraRisp6_t2'] == 'sasso':
        return 0.0
    elif morra['morra6_t2'] == 'Forbice' and morra['morraRisp6_t2'] == 'forbice':
        return 0.1
    else:
        return 'errore'
    
def score_func7_t2(morra):
    """ win or lose? """
    if morra['morra7_t2'] == 'Carta' and morra['morraRisp7_t2'] == 'carta':
        return 0.1
    elif morra['morra7_t2'] == 'Carta' and morra['morraRisp7_t2'] == 'sasso':
        return 1.0
    elif morra['morra7_t2'] == 'Carta' and morra['morraRisp7_t2'] == 'forbice':
        return 0.0
    elif morra['morra7_t2'] == 'Sasso' and morra['morraRisp7_t2'] == 'carta':
        return 0.0
    elif morra['morra7_t2'] == 'Sasso' and morra['morraRisp7_t2'] == 'sasso':
        return 0.1
    elif morra['morra7_t2'] == 'Sasso' and morra['morraRisp7_t2'] == 'forbice':
        return 1.0
    elif morra['morra7_t2'] == 'Forbice' and morra['morraRisp7_t2'] == 'carta':
        return 1.0
    elif morra['morra7_t2'] == 'Forbice' and morra['morraRisp7_t2'] == 'sasso':
        return 0.0
    elif morra['morra7_t2'] == 'Forbice' and morra['morraRisp7_t2'] == 'forbice':
        return 0.1
    else:
        return 'errore'

def score_func8_t2(morra):
    """ win or lose? """
    if morra['morra8_t2'] == 'Carta' and morra['morraRisp8_t2'] == 'carta':
        return 0.1
    elif morra['morra8_t2'] == 'Carta' and morra['morraRisp8_t2'] == 'sasso':
        return 1.0
    elif morra['morra8_t2'] == 'Carta' and morra['morraRisp8_t2'] == 'forbice':
        return 0.0
    elif morra['morra8_t2'] == 'Sasso' and morra['morraRisp8_t2'] == 'carta':
        return 0.0
    elif morra['morra8_t2'] == 'Sasso' and morra['morraRisp8_t2'] == 'sasso':
        return 0.1
    elif morra['morra8_t2'] == 'Sasso' and morra['morraRisp8_t2'] == 'forbice':
        return 1.0
    elif morra['morra8_t2'] == 'Forbice' and morra['morraRisp8_t2'] == 'carta':
        return 1.0
    elif morra['morra8_t2'] == 'Forbice' and morra['morraRisp8_t2'] == 'sasso':
        return 0.0
    elif morra['morra8_t2'] == 'Forbice' and morra['morraRisp8_t2'] == 'forbice':
        return 0.1
    else:
        return 'errore'

def score_func9_t2(morra):
    """ win or lose? """
    if morra['morra9_t2'] == 'Carta' and morra['morraRisp9_t2'] == 'carta':
        return 0.1
    elif morra['morra9_t2'] == 'Carta' and morra['morraRisp9_t2'] == 'sasso':
        return 1.0
    elif morra['morra9_t2'] == 'Carta' and morra['morraRisp9_t2'] == 'forbice':
        return 0.0
    elif morra['morra9_t2'] == 'Sasso' and morra['morraRisp9_t2'] == 'carta':
        return 0.0
    elif morra['morra9_t2'] == 'Sasso' and morra['morraRisp9_t2'] == 'sasso':
        return 0.1
    elif morra['morra9_t2'] == 'Sasso' and morra['morraRisp9_t2'] == 'forbice':
        return 1.0
    elif morra['morra9_t2'] == 'Forbice' and morra['morraRisp9_t2'] == 'carta':
        return 1.0
    elif morra['morra9_t2'] == 'Forbice' and morra['morraRisp9_t2'] == 'sasso':
        return 0.0
    elif morra['morra9_t2'] == 'Forbice' and morra['morraRisp9_t2'] == 'forbice':
        return 0.1
    else:
        return 'errore'

def score_func10_t2(morra):
    """ win or lose? """
    if morra['morra10_t2'] == 'Carta' and morra['morraRisp10_t2'] == 'carta':
        return 0.1
    elif morra['morra10_t2'] == 'Carta' and morra['morraRisp10_t2'] == 'sasso':
        return 1.0
    elif morra['morra10_t2'] == 'Carta' and morra['morraRisp10_t2'] == 'forbice':
        return 0.0
    elif morra['morra10_t2'] == 'Sasso' and morra['morraRisp10_t2'] == 'carta':
        return 0.0
    elif morra['morra10_t2'] == 'Sasso' and morra['morraRisp10_t2'] == 'sasso':
        return 0.1
    elif morra['morra10_t2'] == 'Sasso' and morra['morraRisp10_t2'] == 'forbice':
        return 1.0
    elif morra['morra10_t2'] == 'Forbice' and morra['morraRisp10_t2'] == 'carta':
        return 1.0
    elif morra['morra10_t2'] == 'Forbice' and morra['morraRisp10_t2'] == 'sasso':
        return 0.0
    elif morra['morra10_t2'] == 'Forbice' and morra['morraRisp10_t2'] == 'forbice':
        return 0.1
    else:
        return 'errore'

# %%
# Use hide_toggle(for_next=True)
# OR hide_toggle()
# to hide a cell


from IPython.display import HTML
import random

def hide_toggle(for_next=False):
    this_cell = """$('div.cell.code_cell.rendered.selected')"""
    next_cell = this_cell + '.next()'

    toggle_text = 'Toggle show/hide'  # text shown on toggle link
    target_cell = this_cell  # target cell to control with toggle
    js_hide_current = ''  # bit of JS to permanently hide code in current cell (only when toggling next cell)

    if for_next:
        target_cell = next_cell
        toggle_text += ' next cell'
        js_hide_current = this_cell + '.find("div.input").hide();'

    js_f_name = 'code_toggle_{}'.format(str(random.randint(1,2**64)))

    html = """
        <script>
            function {f_name}() {{
                {cell_selector}.find('div.input').toggle();
            }}

            {js_hide_current}
        </script>

        <a href="javascript:{f_name}()">{toggle_text}</a>
    """.format(
        f_name=js_f_name,
        cell_selector=target_cell,
        js_hide_current=js_hide_current, 
        toggle_text=toggle_text
    )

    return HTML(html)
